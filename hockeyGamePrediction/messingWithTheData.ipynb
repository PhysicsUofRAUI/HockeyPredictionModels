# %%
import pandas as pd

my_data = pd.read_csv("entries_as_rows.csv")

my_data = my_data.dropna()

my_data = my_data.drop('Unnamed: 0', axis=1)


print(my_data)
# Out:
#         team1Player1   team1Player2    team1Player3   team1Player4  \
# 1          M. Darche      B. Gionta        S. Gomez   A. Kostitsyn
# 16        A. Burrows     P. Demitra        T. Glass      J. Hansen
# 20          C. Adams       M. Cooke       S. Crosby      P. Dupuis
# 25         S. Downie     T. Fedoruk      Z. Konopka  V. Lecavalier
# 26          D. Brown       R. Clune       A. Frolov     J. Halpern
# 37         M. Darche      B. Gionta        S. Gomez   A. Kostitsyn
# 43       T. Bertuzzi      D. Cleary      P. Datsyuk      K. Draper
# 44        A. Burrows     P. Demitra        T. Glass      J. Hansen
# 47         M. Darche      B. Gionta        S. Gomez   A. Kostitsyn
# 57        A. Burrows     P. Demitra        T. Glass      J. Hansen
# 60      B. Bochenski      S. Downie      T. Fedoruk  V. Lecavalier
# 67          D. Brown       R. Clune       A. Frolov     J. Halpern
# 73          G. Brule    A. Cogliano       M. Comrie      S. Gagner
# ...

# %%
# players = {}
# count = 0
# for index, row in my_data.iterrows():
#     if row['team1Player1'] in players :
#         my_data.loc[index, 'team1Player1'] = players[row['team1Player1']]
#     else :
#         players[row['team1Player1']] = count
#         my_data.loc[index, 'team1Player1'] = players[row['team1Player1']]
#         count = count + 1
        
#     if row['team1Player2'] in players :
#         my_data.loc[index, 'team1Player2'] = players[row['team1Player2']]
#     else :
#         players[row['team1Player2']] = count
#         my_data.loc[index, 'team1Player2'] = players[row['team1Player2']]
#         count = count + 1
        
#     if row['team1Player4'] in players :
#         my_data.loc[index, 'team1Player4'] = players[row['team1Player4']]
#     else :
#         players[row['team1Player4']] = count
#         my_data.loc[index, 'team1Player4'] = players[row['team1Player4']]
#         count = count + 1
        
#     if row['team1Player3'] in players :
#         my_data.loc[index, 'team1Player3'] = players[row['team1Player3']]
#     else :
#         players[row['team1Player3']] = count
#         my_data.loc[index, 'team1Player3'] = players[row['team1Player3']]
#         count = count + 1
        
#     if row['team1Player5'] in players :
#         my_data.loc[index, 'team1Player5'] = players[row['team1Player5']]
#     else :
#         players[row['team1Player5']] = count
#         my_data.loc[index, 'team1Player5'] = players[row['team1Player5']]
#         count = count + 1
        
#     if row['team1Player6'] in players :
#         my_data.loc[index, 'team1Player6'] = players[row['team1Player6']]
#     else :
#         players[row['team1Player6']] = count
#         my_data.loc[index, 'team1Player6'] = players[row['team1Player6']]
#         count = count + 1
        
#     if row['team1Player7'] in players :
#         my_data.loc[index, 'team1Player7'] = players[row['team1Player7']]
#     else :
#         players[row['team1Player7']] = count
#         my_data.loc[index, 'team1Player7'] = players[row['team1Player7']]
#         count = count + 1
        
#     if row['team1Player8'] in players :
#         my_data.loc[index, 'team1Player8'] = players[row['team1Player8']]
#     else :
#         players[row['team1Player8']] = count
#         my_data.loc[index, 'team1Player8'] = players[row['team1Player8']]
#         count = count + 1
        
#     if row['team1Player9'] in players :
#         my_data.loc[index, 'team1Player9'] = players[row['team1Player9']]
#     else :
#         players[row['team1Player9']] = count
#         my_data.loc[index, 'team1Player9'] = players[row['team1Player9']]
#         count = count + 1
        
#     if row['team1Player10'] in players :
#         my_data.loc[index, 'team1Player10'] = players[row['team1Player10']]
#     else :
#         players[row['team1Player10']] = count
#         my_data.loc[index, 'team1Player10'] = players[row['team1Player10']]
#         count = count + 1
        
#     if row['team1Player11'] in players :
#         my_data.loc[index, 'team1Player11'] = players[row['team1Player11']]
#     else :
#         players[row['team1Player11']] = count
#         my_data.loc[index, 'team1Player11'] = players[row['team1Player11']]
#         count = count + 1
        
#     if row['team1Player12'] in players :
#         my_data.loc[index, 'team1Player12'] = players[row['team1Player12']]
#     else :
#         players[row['team1Player12']] = count
#         my_data.loc[index, 'team1Player12'] = players[row['team1Player12']]
#         count = count + 1
        
#     if row['team1Player13'] in players :
#         my_data.loc[index, 'team1Player13'] = players[row['team1Player13']]
#     else :
#         players[row['team1Player13']] = count
#         my_data.loc[index, 'team1Player13'] = players[row['team1Player13']]
#         count = count + 1
        
#     if row['team1Player14'] in players :
#         my_data.loc[index, 'team1Player14'] = players[row['team1Player14']]
#     else :
#         players[row['team1Player14']] = count
#         my_data.loc[index, 'team1Player14'] = players[row['team1Player14']]
#         count = count + 1
        
#     if row['team1Player16'] in players :
#         my_data.loc[index, 'team1Player16'] = players[row['team1Player16']]
#     else :
#         players[row['team1Player16']] = count
#         my_data.loc[index, 'team1Player16'] = players[row['team1Player16']]
#         count = count + 1
        
#     if row['team1Player15'] in players :
#         my_data.loc[index, 'team1Player15'] = players[row['team1Player15']]
#     else :
#         players[row['team1Player15']] = count
#         my_data.loc[index, 'team1Player15'] = players[row['team1Player15']]
#         count = count + 1
        
#     if row['team1Player17'] in players :
#         my_data.loc[index, 'team1Player17'] = players[row['team1Player17']]
#     else :
#         players[row['team1Player17']] = count
#         my_data.loc[index, 'team1Player17'] = players[row['team1Player17']]
#         count = count + 1
        
#     if row['team1Player18'] in players :
#         my_data.loc[index, 'team1Player18'] = players[row['team1Player18']]
#     else :
#         players[row['team1Player18']] = count
#         my_data.loc[index, 'team1Player18'] = players[row['team1Player18']]
#         count = count + 1
        
#     if row['team1Golie1'] in players :
#         my_data.loc[index, 'team1Golie1'] = players[row['team1Golie1']]
#     else :
#         players[row['team1Golie1']] = count
#         my_data.loc[index, 'team1Golie1'] = players[row['team1Golie1']]
#         count = count + 1
        
#     if row['team2Player1'] in players :
#         my_data.loc[index, 'team2Player1'] = players[row['team2Player1']]
#     else :
#         players[row['team2Player1']] = count
#         my_data.loc[index, 'team2Player1'] = players[row['team2Player1']]
#         count = count + 1
        
#     if row['team2Player2'] in players :
#         my_data.loc[index, 'team2Player2'] = players[row['team2Player2']]
#     else :
#         players[row['team2Player2']] = count
#         my_data.loc[index, 'team2Player2'] = players[row['team2Player2']]
#         count = count + 1
        
#     if row['team2Player4'] in players :
#         my_data.loc[index, 'team2Player4'] = players[row['team2Player4']]
#     else :
#         players[row['team2Player4']] = count
#         my_data.loc[index, 'team2Player4'] = players[row['team2Player4']]
#         count = count + 1
        
#     if row['team2Player3'] in players :
#         my_data.loc[index, 'team2Player3'] = players[row['team2Player3']]
#     else :
#         players[row['team2Player3']] = count
#         my_data.loc[index, 'team2Player3'] = players[row['team2Player3']]
#         count = count + 1
        
#     if row['team2Player5'] in players :
#         my_data.loc[index, 'team2Player5'] = players[row['team2Player5']]
#     else :
#         players[row['team2Player5']] = count
#         my_data.loc[index, 'team2Player5'] = players[row['team2Player5']]
#         count = count + 1
        
#     if row['team2Player6'] in players :
#         my_data.loc[index, 'team2Player6'] = players[row['team2Player6']]
#     else :
#         players[row['team2Player6']] = count
#         my_data.loc[index, 'team2Player6'] = players[row['team2Player6']]
#         count = count + 1
        
#     if row['team2Player7'] in players :
#         my_data.loc[index, 'team2Player7'] = players[row['team2Player7']]
#     else :
#         players[row['team2Player7']] = count
#         my_data.loc[index, 'team2Player7'] = players[row['team2Player7']]
#         count = count + 1
        
#     if row['team2Player8'] in players :
#         my_data.loc[index, 'team2Player8'] = players[row['team2Player8']]
#     else :
#         players[row['team2Player8']] = count
#         my_data.loc[index, 'team2Player8'] = players[row['team2Player8']]
#         count = count + 1
        
#     if row['team2Player9'] in players :
#         my_data.loc[index, 'team2Player9'] = players[row['team2Player9']]
#     else :
#         players[row['team2Player9']] = count
#         my_data.loc[index, 'team2Player9'] = players[row['team2Player9']]
#         count = count + 1
        
#     if row['team2Player10'] in players :
#         my_data.loc[index, 'team2Player10'] = players[row['team2Player10']]
#     else :
#         players[row['team2Player10']] = count
#         my_data.loc[index, 'team2Player10'] = players[row['team2Player10']]
#         count = count + 1
        
#     if row['team2Player11'] in players :
#         my_data.loc[index, 'team2Player11'] = players[row['team2Player11']]
#     else :
#         players[row['team2Player11']] = count
#         my_data.loc[index, 'team2Player11'] = players[row['team2Player11']]
#         count = count + 1
        
#     if row['team2Player12'] in players :
#         my_data.loc[index, 'team2Player12'] = players[row['team2Player12']]
#     else :
#         players[row['team2Player12']] = count
#         my_data.loc[index, 'team2Player12'] = players[row['team2Player12']]
#         count = count + 1
        
#     if row['team2Player13'] in players :
#         my_data.loc[index, 'team2Player13'] = players[row['team2Player13']]
#     else :
#         players[row['team2Player13']] = count
#         my_data.loc[index, 'team2Player13'] = players[row['team2Player13']]
#         count = count + 1
        
#     if row['team2Player14'] in players :
#         my_data.loc[index, 'team2Player14'] = players[row['team2Player14']]
#     else :
#         players[row['team2Player14']] = count
#         my_data.loc[index, 'team2Player14'] = players[row['team2Player14']]
#         count = count + 1
        
#     if row['team2Player16'] in players :
#         my_data.loc[index, 'team2Player16'] = players[row['team2Player16']]
#     else :
#         players[row['team2Player16']] = count
#         my_data.loc[index, 'team2Player16'] = players[row['team2Player16']]
#         count = count + 1
        
#     if row['team2Player15'] in players :
#         my_data.loc[index, 'team2Player15'] = players[row['team2Player15']]
#     else :
#         players[row['team2Player15']] = count
#         my_data.loc[index, 'team2Player15'] = players[row['team2Player15']]
#         count = count + 1
        
#     if row['team2Player17'] in players :
#         my_data.loc[index, 'team2Player17'] = players[row['team2Player17']]
#     else :
#         players[row['team2Player17']] = count
#         my_data.loc[index, 'team2Player17'] = players[row['team2Player17']]
#         count = count + 1
        
#     if row['team2Player18'] in players :
#         my_data.loc[index, 'team2Player18'] = players[row['team2Player18']]
#     else :
#         players[row['team2Player18']] = count
#         my_data.loc[index, 'team2Player18'] = players[row['team2Player18']]
#         count = count + 1
        
#     if row['team2Golie1'] in players :
#         my_data.loc[index, 'team2Golie1'] = players[row['team2Golie1']]
#     else :
#         players[row['team2Golie1']] = count
#         my_data.loc[index, 'team2Golie1'] = players[row['team2Golie1']]
#         count = count + 1

# print(count)
# my_data.to_csv("players_as_numbers.csv")        
# print(my_data)

# %%
my_data.to_csv("NoBlanksAndScoreAsDummy.csv")
